0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.7.0) (1.15.0)
# Requirement already satisfied: numpy>=1.14.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.7.0) (1.24.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.7.0) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.7.0) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.7.0) (3.7.4.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (67.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (5.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2022.9.24)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.6->tensorflow==2.7.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, flatbuffers, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.1.21
#     Uninstalling flatbuffers-23.1.21:
#       Successfully uninstalled flatbuffers-23.1.21
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed flatbuffers-2.0.7 keras-2.7.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.11.0 requires keras<2.12,>=2.11.0, but you have keras 2.7.0 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorflow-estimator<2.12,>=2.11.0, but you have tensorflow-estimator 2.7.0 which is incompatible.
# keras-rl 0.3.1 requires keras<2.0.7,>=1.0.7, but you have keras 2.7.0 which is incompatible.
# Requirement already satisfied: gym in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (0.26.2)
# Requirement already satisfied: importlib-metadata>=4.8.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from gym) (5.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from gym) (2.2.1)
# Requirement already satisfied: numpy>=1.18.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from gym) (1.24.2)
# Requirement already satisfied: zipp>=0.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.11.0)
# Requirement already satisfied: keras in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (2.7.0)
# Requirement already satisfied: keras-rl2 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (1.0.5)
# Requirement already satisfied: tensorflow in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from keras-rl2) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (3.19.6)
# Requirement already satisfied: absl-py>=0.4.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.34.1)
# Requirement already satisfied: six>=1.12.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: numpy>=1.14.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.24.2)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (2.0.7)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (0.28.0)
# Requirement already satisfied: libclang>=9.0.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (14.0.6)
# Requirement already satisfied: tensorboard~=2.6 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (2.11.2)
# Requirement already satisfied: termcolor>=1.1.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (0.38.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (3.7.4.3)
# Requirement already satisfied: h5py>=2.9.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.28.2)
# Requirement already satisfied: setuptools>=41.0.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (67.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-rl2) (5.1.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2022.9.24)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.6->tensorflow->keras-rl2) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow->keras-rl2) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\psych\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (3.2.2)

# %%
from gym import Env
from gym.spaces import Discrete, Box
from nextState import *
from serializer import *
import numpy as np
import random
import json

# %%
NUM_STATES = 1

## Action selector
## Process the results
## Return the next world state

class SMTEnv(Env):
    def __init__(self):
        # Actions we can take (8 moves, 3 targets)
        self.action_space_moves = Discrete(8)
        self.action_space_targets = Discrete(3)

        ## World state + agent state

        # Resistance array
        self.observation_space = Box(low=np.array([0, 0, 0, 0]), high=np.array([3, 3, 3, 3]))
        
        self.runs = 0
        
        self.state = {}

        # Sets game as playable
        self.in_progress = True

    def step(self, action):

        # Agent performs an action
        # Look at world state and figure out how action affects the world state
        
        self.state = nextState(self.filename, action)
        
        if self.state["complete"] == True:
            self.in_progress = False

        # Calculate reward
        if self.in_progress == False and self.state["party1"]["player"]["battleStats"]["hp"] <= 0:
            reward = -1000
        elif self.in_progress == False:
            reward = 1000
        else:
            reward = -1

        # Check if battle is done
        if self.in_progress == True:
            done = False
        else:
            done = True

        # Set placeholder for info
        info = {}

        # Return step information
        return self.state, reward, done, info

    def render(self):
        pass

    def reset(self):        
        # Reset state
        stateID = random.randrange(0, NUM_STATES)
        rf = open("./states/state" + str(stateID) + ".json")
        data = json.load(rf)
        jsonData = to_json(data)
        wf = open("./completedStates/state" + str(self.runs) + ".json", "w")
        wf.write(jsonData)
        f = open("./completedStates/state" + str(self.runs) + ".json")
        self.state = json.load(f)
        self.filename = "./completedStates/state" + str(self.runs) + ".json"

        # Resets game to playable
        self.in_progress = True

        self.runs += 1
        return self.state

# %%
def chooseRandom():
    return [random.randrange(0, 8), random.randrange(0, 3)]

# %%
env = SMTEnv()

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        
        # Ask who's turn it is, if agent continue
        if state["turn"][0] == 0:
            action = [env.action_space_moves.sample(), env.action_space_targets.sample()]
            n_state, reward, done, info = env.step(action)
            score += reward
        # Else choose a random action from the opposing team 
        else:
            action = chooseRandom()
            env.step(action)
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:972
# Episode:2 Score:972
# Episode:3 Score:972
# Episode:4 Score:-1080
# Episode:5 Score:-1096
# Episode:6 Score:-1032
# Episode:7 Score:-1016
# Episode:8 Score:956
# Episode:9 Score:-1088
# Episode:10 Score:-1056

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
Adam._name = 'hey'

# %%
states = env.observation_space.shape
actions = (3 * (env.action_space_moves.n - 1)) + env.action_space_targets.n

# %%
def build_model(states, actions):
    model = Sequential()
    model.add(Dense(24, activation='relu', input_shape=states))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
del model

# %%
model = build_model(states, actions)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                600
# =================================================================
# Total params: 1,320
# Trainable params: 1,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from rl.agents import DQNAgent
#       2 from rl.policy import BoltzmannQPolicy
#       3 from rl.memory import SequentialMemory
#
# File d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\rl\agents\__init__.py:2
#       1 from __future__ import absolute_import
# ----> 2 from .dqn import DQNAgent, NAFAgent, ContinuousDQNAgent
#       3 from .ddpg import DDPGAgent
#       4 from .cem import CEMAgent
#
# File d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\rl\agents\dqn.py:4
#       1 from __future__ import division
#       2 import warnings
# ----> 4 import keras.backend as K
#       5 from keras.layers import Lambda, Input, Layer, Dense
#       7 from rl.core import Agent
#
# File d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\__init__.py:22
#      20 # pylint: disable=unused-import
#      21 from tensorflow.python import tf2
# ---> 22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
#      25 from keras import models
#
# File d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\distribute\__init__.py:18
#      15 """Keras' Distribution Strategy library."""
#      17 # pylint: disable=unused-import
# ---> 18 from keras.distribute import sidecar_evaluator
#
# File d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\distribute\sidecar_evaluator.py:18
#       1 # Lint as: python3
#       2 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       3 #
#    (...)
#      14 # limitations under the License.
#      15 # ==============================================================================
#      16 """Python module for evaluation loop."""
# ---> 18 import tensorflow.compat.v2 as tf
#      19 from tensorflow.python.platform import tf_logging as logging
#      20 from tensorflow.python.util.tf_export import keras_export  # pylint: disable=g-direct-tensorflow-import
#
# ModuleNotFoundError: No module named 'tensorflow.compat'

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy,
        nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
dqn = build_agent(model, actions)
dqn.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), metrics=['mae'])
dqn.fit(env, nb_steps=50000, visualize=False, verbose=1)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function mean_q at 0x00000258B3D23430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: expected exactly one node, got [<gast.gast.ImportFrom object at 0x00000258B69B74C0>, <gast.gast.Import object at 0x00000258B69B7520>, <gast.gast.Import object at 0x00000258B69B7550>, <gast.gast.ImportFrom object at 0x00000258B69B74F0>, <gast.gast.ImportFrom object at 0x00000258B69B7580>, <gast.gast.ImportFrom object at 0x00000258B69B75B0>, <gast.gast.ImportFrom object at 0x00000258B69B7640>, <gast.gast.ImportFrom object at 0x00000258B69B72E0>, <gast.gast.FunctionDef object at 0x00000258B69B7130>]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function mean_q at 0x00000258B3D23430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: expected exactly one node, got [<gast.gast.ImportFrom object at 0x00000258B69B74C0>, <gast.gast.Import object at 0x00000258B69B7520>, <gast.gast.Import object at 0x00000258B69B7550>, <gast.gast.ImportFrom object at 0x00000258B69B74F0>, <gast.gast.ImportFrom object at 0x00000258B69B7580>, <gast.gast.ImportFrom object at 0x00000258B69B75B0>, <gast.gast.ImportFrom object at 0x00000258B69B7640>, <gast.gast.ImportFrom object at 0x00000258B69B72E0>, <gast.gast.FunctionDef object at 0x00000258B69B7130>]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function mean_q at 0x00000258B3D23430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: expected exactly one node, got [<gast.gast.ImportFrom object at 0x00000258B69B74C0>, <gast.gast.Import object at 0x00000258B69B7520>, <gast.gast.Import object at 0x00000258B69B7550>, <gast.gast.ImportFrom object at 0x00000258B69B74F0>, <gast.gast.ImportFrom object at 0x00000258B69B7580>, <gast.gast.ImportFrom object at 0x00000258B69B75B0>, <gast.gast.ImportFrom object at 0x00000258B69B7640>, <gast.gast.ImportFrom object at 0x00000258B69B72E0>, <gast.gast.FunctionDef object at 0x00000258B69B7130>]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E430> and will run it as-is.
# Cause: could not parse the source code of <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E430>: no matching AST found among candidates:
# # coding=utf-8
# lambda y_true, y_pred: y_pred
# # coding=utf-8
# lambda y_true, y_pred: K.zeros_like(y_pred)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.mean(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.max(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E430> and will run it as-is.
# Cause: could not parse the source code of <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E430>: no matching AST found among candidates:
# # coding=utf-8
# lambda y_true, y_pred: y_pred
# # coding=utf-8
# lambda y_true, y_pred: K.zeros_like(y_pred)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.mean(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.max(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E430> and will run it as-is.
# Cause: could not parse the source code of <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E430>: no matching AST found among candidates:
# # coding=utf-8
# lambda y_true, y_pred: y_pred
# # coding=utf-8
# lambda y_true, y_pred: K.zeros_like(y_pred)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.mean(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.max(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E4C0> and will run it as-is.
# Cause: could not parse the source code of <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E4C0>: no matching AST found among candidates:
# # coding=utf-8
# lambda y_true, y_pred: y_pred
# # coding=utf-8
# lambda y_true, y_pred: K.zeros_like(y_pred)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.mean(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.max(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E4C0> and will run it as-is.
# Cause: could not parse the source code of <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E4C0>: no matching AST found among candidates:
# # coding=utf-8
# lambda y_true, y_pred: y_pred
# # coding=utf-8
# lambda y_true, y_pred: K.zeros_like(y_pred)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.mean(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.max(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E4C0> and will run it as-is.
# Cause: could not parse the source code of <function DQNAgent.compile.<locals>.<lambda> at 0x00000258B695E4C0>: no matching AST found among candidates:
# # coding=utf-8
# lambda y_true, y_pred: y_pred
# # coding=utf-8
# lambda y_true, y_pred: K.zeros_like(y_pred)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.mean(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - K.max(a[:, 1:], keepdims=True)
# # coding=utf-8
# lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:]
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\psych\AppData\Local\Temp\ipykernel_2072\2323014487.py", line 3, in <module>
#     dqn.fit(env, nb_steps=50000, visualize=False, verbose=1)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\rl\core.py", line 168, in fit
#     observation, r, done, info = env.step(action)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\rl\agents\dqn.py", line 224, in forward
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\rl\agents\dqn.py", line 68, in compute_q_values
#     def compute_q_values(self, state):
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\rl\agents\dqn.py", line 63, in compute_batch_q_values
#     batch = self.process_state_batch(state_batch)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training_v1.py", line 1303, in predict_on_batch
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training_v1.py", line 2650, in _standardize_user_data
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training_v1.py", line 2691, in _standardize_tensors
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training_utils_v1.py", line 731, in standardize_input_data
# ValueError: Error when checking input: expected dense_24_input to have shape (4,) but got array with shape (1,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#   File "d:\users\psych\appdata\local\programs\python\python39\lib\site-packages\executing\executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
